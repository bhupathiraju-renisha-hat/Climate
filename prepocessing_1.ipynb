# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath= ("/Users/bhupathiraju_renisha/Desktop/Climate/merged_data.csv")

# %%
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#         datetime (UTC)   coordinates (lat,lon) model (name)_x  \
# 0  2005-01-01 00:00:00  (17.361362, 78.474525)           era5
# 1  2005-01-01 01:00:00  (17.361362, 78.474525)           era5
# 2  2005-01-01 02:00:00  (17.361362, 78.474525)           era5
# 3  2005-01-01 03:00:00  (17.361362, 78.474525)           era5
# 4  2005-01-01 04:00:00  (17.361362, 78.474525)           era5
#
#    model elevation (surface)_x  utc_offset (hrs)_x  temperature (degC)  \
# 0                       563.89                 5.5               17.94
# 1                       563.89                 5.5               17.92
# 2                       563.89                 5.5               19.86
# 3                       563.89                 5.5               20.47
# 4                       563.89                 5.5               21.34
#
#    total_precipitation (mm of water equivalent) model (name)_y  \
# 0                                           0.0           era5
# ...

# %%
df.tail()
# Out:
#              datetime (UTC)   coordinates (lat,lon) model (name)_x  \
# 175315  2024-12-31 19:00:00  (17.361362, 78.474525)           era5
# 175316  2024-12-31 20:00:00  (17.361362, 78.474525)           era5
# 175317  2024-12-31 21:00:00  (17.361362, 78.474525)           era5
# 175318  2024-12-31 22:00:00  (17.361362, 78.474525)           era5
# 175319  2024-12-31 23:00:00  (17.361362, 78.474525)           era5
#
#         model elevation (surface)_x  utc_offset (hrs)_x  temperature (degC)  \
# 175315                       563.89                 5.5               21.07
# 175316                       563.89                 5.5               19.95
# 175317                       563.89                 5.5               19.30
# 175318                       563.89                 5.5               18.76
# 175319                       563.89                 5.5               18.23
#
#         total_precipitation (mm of water equivalent) model (name)_y  \
# ...

# %%
df.shape
# Out:
# (175320, 16)

# %%
df.info
# Out:
# <bound method DataFrame.info of              datetime (UTC)   coordinates (lat,lon) model (name)_x  \
# 0       2005-01-01 00:00:00  (17.361362, 78.474525)           era5
# 1       2005-01-01 01:00:00  (17.361362, 78.474525)           era5
# 2       2005-01-01 02:00:00  (17.361362, 78.474525)           era5
# 3       2005-01-01 03:00:00  (17.361362, 78.474525)           era5
# 4       2005-01-01 04:00:00  (17.361362, 78.474525)           era5
# ...                     ...                     ...            ...
# 175315  2024-12-31 19:00:00  (17.361362, 78.474525)           era5
# 175316  2024-12-31 20:00:00  (17.361362, 78.474525)           era5
# 175317  2024-12-31 21:00:00  (17.361362, 78.474525)           era5
# 175318  2024-12-31 22:00:00  (17.361362, 78.474525)           era5
# 175319  2024-12-31 23:00:00  (17.361362, 78.474525)           era5
#
#         model elevation (surface)_x  utc_offset (hrs)_x  temperature (degC)  \
# ...

# %%
df.info (0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175320 entries, 0 to 175319
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   datetime (UTC)                                175320 non-null  object
#  1   coordinates (lat,lon)                         175320 non-null  object
#  2   model (name)_x                                175320 non-null  object
#  3   model elevation (surface)_x                   175320 non-null  float64
#  4   utc_offset (hrs)_x                            175320 non-null  float64
#  5   temperature (degC)                            175320 non-null  float64
#  6   total_precipitation (mm of water equivalent)  175320 non-null  float64
#  7   model (name)_y                                175320 non-null  object
#  8   model elevation (surface)_y                   175320 non-null  float64
# ...

# %%
df.dtypes
# Out:
# datetime (UTC)                                   object
# coordinates (lat,lon)                            object
# model (name)_x                                   object
# model elevation (surface)_x                     float64
# utc_offset (hrs)_x                              float64
# temperature (degC)                              float64
# total_precipitation (mm of water equivalent)    float64
# model (name)_y                                   object
# model elevation (surface)_y                     float64
# utc_offset (hrs)_y                              float64
# relative_humidity (0-1)                         float64
# model (name)                                     object
# model elevation (surface)                       float64
# utc_offset (hrs)                                float64
# 10m_u_component_of_wind (m/s)                   float64
# 10m_v_component_of_wind (m/s)                   float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# datetime (UTC)                                  0
# coordinates (lat,lon)                           0
# model (name)_x                                  0
# model elevation (surface)_x                     0
# utc_offset (hrs)_x                              0
# temperature (degC)                              0
# total_precipitation (mm of water equivalent)    0
# model (name)_y                                  0
# model elevation (surface)_y                     0
# utc_offset (hrs)_y                              0
# relative_humidity (0-1)                         0
# model (name)                                    0
# model elevation (surface)                       0
# utc_offset (hrs)                                0
# 10m_u_component_of_wind (m/s)                   0
# 10m_v_component_of_wind (m/s)                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# datetime (UTC)
# 2005-01-01 00:00:00    1
# 2018-05-03 03:00:00    1
# 2018-05-02 19:00:00    1
# 2018-05-02 20:00:00    1
# 2018-05-02 21:00:00    1
#                       ..
# 2011-09-02 01:00:00    1
# 2011-09-02 02:00:00    1
# 2011-09-02 03:00:00    1
# 2011-09-02 04:00:00    1
# 2024-12-31 23:00:00    1
# Name: count, Length: 175320, dtype: int64
# ******************************
# coordinates (lat,lon)
# (17.361362, 78.474525)    175320
# Name: count, dtype: int64
# ******************************
# model (name)_x
# era5    175320
# Name: count, dtype: int64
# ******************************
# model (name)_y
# era5    175320
# Name: count, dtype: int64
# ******************************
# model (name)
# era5    175320
# Name: count, dtype: int64
# ******************************

# %%
columns_to_drop = ['model (name)_x', 'model (name)_y', 
    'model elevation (surface)_x', 'model elevation (surface)_y', 
    'utc_offset (hrs)_x', 'utc_offset (hrs)_y']

# %%
df_cleaned = df.drop(columns=columns_to_drop)

# %%
print(df_cleaned.head())
# Out:
#         datetime (UTC)   coordinates (lat,lon)  temperature (degC)  \
# 0  2005-01-01 00:00:00  (17.361362, 78.474525)               17.94
# 1  2005-01-01 01:00:00  (17.361362, 78.474525)               17.92
# 2  2005-01-01 02:00:00  (17.361362, 78.474525)               19.86
# 3  2005-01-01 03:00:00  (17.361362, 78.474525)               20.47
# 4  2005-01-01 04:00:00  (17.361362, 78.474525)               21.34
#
#    total_precipitation (mm of water equivalent)  relative_humidity (0-1)  \
# 0                                           0.0                     0.91
# 1                                           0.0                     0.93
# 2                                           0.0                     0.87
# 3                                           0.0                     0.82
# 4                                           0.0                     0.75
#
#   model (name)  model elevation (surface)  utc_offset (hrs)  \
# ...

# %%
df_cleaned.to_csv('/Users/bhupathiraju_renisha/Desktop/Climate/cleaned_data.csv', index=False)
